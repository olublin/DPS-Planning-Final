# %%
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
gpd.read_file('/Users/leahwallihan/Durham_school_planning/DPS-Planning-Final/data/pu_2324_SPLIT.geojson')
# Out:
#      OBJECTID  pu_2324_84             X              Y  M_min  PS_ID  \
# 0           1           1  2.049028e+06  893128.606346    0.0    589
# 1           2           2  2.039923e+06  835434.121317    0.0    401
# 2           3           3  2.058005e+06  797649.028742    0.0    782
# 3           4           4  2.003222e+06  772895.737307    0.0    201
# 4           5           5  2.067334e+06  828244.230730    0.0    646
# ..        ...         ...           ...            ...    ...    ...
# 846       844         844  2.011851e+06  824885.632280    0.0    468
# 847       845         845  2.018359e+06  853286.849340    0.0    329
# 848       846         846  2.016360e+06  858711.587472    0.0    573
# 849       847         847  2.013328e+06  854621.040074    0.0    322
# 850       848         848  2.032661e+06  834741.061398    0.0    511
#
#     PUID2122_2  ps_id_833  psid_982  TIMS_PU     Region  Shape_Length  \
# ...

# %%
gpd.read_file('/Users/leahwallihan/Durham_school_planning/DPS-Planning-Final/data/hs_full_geo.geojson')
# Out:
#      pu_2324_84             X              Y     Region    Shape_Area  count  \
# 0             1  2.049028e+06  893128.606346      North  3.556198e+07    6.0
# 1             2  2.039923e+06  835434.121317      North  2.080136e+07   18.0
# 2             3  2.058005e+06  797649.028742       East  1.329077e+07    4.0
# 3             4  2.003222e+06  772895.737307  Southwest  4.684140e+07    6.0
# 4             5  2.067334e+06  828244.230730       East  1.497046e+08    6.0
# ..          ...           ...            ...        ...           ...    ...
# 846         847  2.013328e+06  854621.040074      North  3.748151e+06    0.0
# 847         848  2.032661e+06  834741.061398      North  1.033344e+06   25.0
# 848         849  2.040116e+06  820883.548010      North  2.898398e+07    0.0
# 849         850  2.021058e+06  850561.862179      North  3.356653e+07    0.0
# 850         851  2.020332e+06  809465.029698  Southwest  4.525577e+06   65.0
#
# ...
