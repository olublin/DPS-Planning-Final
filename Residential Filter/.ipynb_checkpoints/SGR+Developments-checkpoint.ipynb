# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
sgr_data = pd.read_csv(r'C:/Users/kevan/OneDrive/Desktop/Data+/SGR_Region.csv')
sgr_data = sgr_data.drop([0,1,2,3])
sgr_data = sgr_data.dropna()
sgr_data = sgr_data[['housing_type','region','parcel_ct','sgr_dps_avg_k12']]
sgr_data['sgr_dps_avg_k12'] = sgr_data['sgr_dps_avg_k12'].round(4)
sgr_data['region'].unique()

sgr_data.head(50)
# Out:
#     housing_type     region  parcel_ct  sgr_dps_avg_k12
# 4   age_restrict    Central        6.0           0.0108
# 5          condo    Central       51.0           0.0237
# 6         du_tri    Central     1289.0           0.2182
# 7            hud    Central       36.0           0.2296
# 8          manuf    Central        5.0           0.4583
# 9         mf_apt    Central      316.0           0.1646
# 11     sf_attach    Central      197.0           0.0330
# 12     sf_detach    Central     8974.0           0.2622
# 13          temp    Central      102.0           0.0617
# 14  age_restrict       East        5.0           0.0342
# 15         condo       East       11.0           0.5740
# 16        du_tri       East       65.0           0.4071
# 17           hud       East        4.0           0.0000
# 18         manuf       East      329.0           0.5281
# 19        mf_apt       East       27.0           0.2154
# 21     sf_attach       East     2864.0           0.0697
# 22     sf_detach       East    18865.0           0.2184
# 23          temp       East       25.0           0.0192
# 24  age_restrict      North       14.0           0.0012
# 25         condo      North       13.0           0.1182
# 26        du_tri      North      183.0           0.3792
# 27           hud      North       82.0           1.0160
# 28         manuf      North      416.0           0.2975
# 29        mf_apt      North       80.0           0.3542
# 31     sf_attach      North     2326.0           0.1012
# 32     sf_detach      North    19955.0           0.2687
# 33          temp      North       34.0           0.0122
# 34  age_restrict  Southeast       10.0           0.0011
# 35         condo  Southeast       18.0           0.0684
# 36        du_tri  Southeast      188.0           0.2552
# 37           hud  Southeast       10.0           0.7563
# 38         manuf  Southeast       30.0           0.6163
# 39        mf_apt  Southeast      119.0           0.1318
# 41     sf_attach  Southeast     5820.0           0.0588
# 42     sf_detach  Southeast    12904.0           0.2150
# 43          temp  Southeast       41.0           0.9167
# 44  age_restrict  Southwest       25.0           0.0034
# 45         condo  Southwest      137.0           0.0380
# 46        du_tri  Southwest      481.0           0.1886
# 47           hud  Southwest        8.0           0.5169
# 48         manuf  Southwest        7.0           0.5000
# 49        mf_apt  Southwest      301.0           0.1873
# 51     sf_attach  Southwest     4848.0           0.0764
# 52     sf_detach  Southwest    18056.0           0.2364
# 53          temp  Southwest       57.0           0.2675

# %%
#read in shapefile to get geometries for regions
regions=gpd.read_file(r'C:/Users/kevan/OneDrive/Desktop/Data+/High_School_Regions')
regions=regions[['ShortName','geometry']]
regions.columns=['region','geometry']
regions['region'].unique()
# Out:
# array(['Riverside', 'Southern School of Energy and Sustainability',
#        'Northern', 'Jordan', 'Hillside'], dtype=object)

# %%
#rename schools to regions in order to merge dfs
regions['region'] = regions['region'].replace({
    'Jordan': 'Southwest',
    'Southern School of Energy and Sustainability': 'East',
    'Northern': 'North',
    'Riverside': 'Central',
    'Hillside': 'Southeast'
})
regions
# Out:
#       region                                           geometry
# 0    Central  POLYGON ((-8782375.398 4299864.415, -8782373.8...
# 1       East  POLYGON ((-8766563.024 4304785.671, -8765329.2...
# 2      North  POLYGON ((-8786141.664 4333538.2, -8784813.632...
# 3  Southwest  POLYGON ((-8789483.599 4298338.617, -8789456.2...
# 4  Southeast  POLYGON ((-8780836.781 4297578.515, -8780421.0...

# %%
sgr_data = sgr_data.merge(regions, on='region')

# %%
#use dictionaries to break down dataframe by region/housing type
sgr_reg = {
    reg:sgr_data[sgr_data['region']==reg]
    for reg in sgr_data['region'].unique()
}
sgr_housing_type = {
    parcel:sgr_data[sgr_data['housing_type']==parcel]
    for parcel in sgr_data['housing_type'].unique()
}

# %%
detach = sgr_housing_type['sf_detach']
detach = gpd.GeoDataFrame(detach, geometry = 'geometry')
detach
# Out:
#    housing_type     region  parcel_ct  sgr_dps_avg_k12  \
# 7     sf_detach    Central     8974.0           0.2622
# 16    sf_detach       East    18865.0           0.2184
# 25    sf_detach      North    19955.0           0.2687
# 34    sf_detach  Southeast    12904.0           0.2150
# 43    sf_detach  Southwest    18056.0           0.2364
#
#                                              geometry
# 7   POLYGON ((-8782375.398 4299864.415, -8782373.8...
# 16  POLYGON ((-8766563.024 4304785.671, -8765329.2...
# 25  POLYGON ((-8786141.664 4333538.2, -8784813.632...
# 34  POLYGON ((-8780836.781 4297578.515, -8780421.0...
# 43  POLYGON ((-8789483.599 4298338.617, -8789456.2...

# %%
column = 'sgr_dps_avg_k12'
vmin = detach[column].min
vmax = detach[column].max

detach.plot(
    column = column,
    cmap = 'Reds',
    legend = True
)
plt.title('DPS Regions by average SGR for Single Family Detached')
plt.show()
