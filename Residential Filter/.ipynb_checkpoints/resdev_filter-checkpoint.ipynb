# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import re

# %%
# read in shapefile file
'''
read in shapefile -- filepaths below
Kevan: r'C:\\Users\kevan\\OneDrive\\Desktop\\Data+\\DevCasesSHP\\Development_Cases.shp'
Leah: '/Users/leahwallihan/Durham_school_planning/geospatial files/Res_Development'
'''
all_cases = gpd.read_file('/Users/leahwallihan/Durham_school_planning/geospatial files/Res_Development')

# %%
# types = A_TYPE codes we want to keep
types = ['PL_MINSP', 'PL_SSP_SM', 'PL_SSM_SM2', 'PL_CPAA', 'PL_MINPP', 'PL_MAJSP', 'PL_MAJSUP', 'PL_PPA', 'PL_MAJPP'] 
# filter that only keeps cases of specified types
filter_cases_type = all_cases[all_cases['A_TYPE'].isin(types)]
# status = A_STATUS codes we want to keep
status = all_cases['A_STATUS'].unique()
status = status[~np.isin(status, ['WITH', 'VOID','DEN','DISAP','EXP'])]
# filter that only keeps cases of specified status
filter_cases_status = filter_cases_type[filter_cases_type['A_STATUS'].isin(status)]

# %%
keywords = ['home', 'family', 'residen', 'mixed', 'mized', 'duplex', 'apartment', ' housing', 'condo', 'dwelling', 'tenant', 'affordable', 'units', 'townhouse']
pattern = '|'.join(keywords)
filtered1 = filter_cases_status[filter_cases_status['A_DESCRIPT'].str.contains(pattern, case=False, na=False)]

#use not pattern to avoid these words
keywords_avoid = ['expand','storage']
pattern_avoid = '|'.join(keywords_avoid)
filtered2 = filtered1[~filtered1['A_DESCRIPT'].str.contains(pattern_avoid, case=False, na=False)]

# %%
#filter for all status dates after 2020
filtered2['A_STATUS_D'] = pd.to_datetime(filtered2['A_STATUS_D'])
filtered3 = filtered2[filtered2['A_STATUS_D'].dt.year>=2020]
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
#define extract_units function number 1

# def normalize_for_regex(term):
#     return re.sub(r'[-\s]+', r'\\s*-?\\s*', term)

# def extract_units1(description):
#     # Remove square footage
#     description = re.sub(
#         r'(\d+|\d{1,3}(,\d{3})*)(\s+[A-Za-z-]+){0,2}?\s*(SF|square feet|sq\.?\s*ft\.?|sqft)',
#         '', description, flags=re.IGNORECASE
#     )

#     # Housing normalization, THIS MEANS THAT IF HOUSES->HOME, S-F -> SINGLE FAMILY, ETC.
#     term_map = {
#         "home": "home", "homes": "home", "house": "home", "houses": "home",
#         "duplex": "duplex", "duplexes": "duplex",
#         "condo": "condo", "condominium": "condo", "condominiums": "condo", "condos": "condo", 
#         "apartment": "apartment", "apartments": "apartment",
#         "townhome": "townhouse", "townhomes": "townhouse",
#         "townhouse": "townhouse", "townhouses": "townhouse",
#         "town home": "townhouse", "town homes": "townhouse",
#         "town house": "townhouse", "town houses": "townhouse",
#         "multifamily": "multifamily", "multi-family": "multifamily", "multi - family": "multifamily", "multi family": "multifamily",
#         "MF": "multifamily", "mutifamily": "multifamily",
#         "single family": "single family", "single-family": "single family", 
#         "single - family": "single family", "s-f": "single family", "s - f": "single family", "s f": "single family"
#     }

#     # Optional leading and trailing terms
#     modifiers = ["attached", "detached"]
#     suffixes = ["units", "lots", "homes", "houses"]

#     # Build regex patterns
#     housing_pattern = "|".join([normalize_for_regex(term) for term in term_map])
#     modifier_pattern = "|".join(modifiers)
#     suffix_pattern = "|".join(suffixes)

#     match_pattern = rf'''
#         \b
#         (?P<qty>\d{{1,4}})
#         \s+
#         (?:(?P<mod>{modifier_pattern})\s+)?
#         (?:[A-Za-z-]+\s+){{0,2}}?
#         (?P<type>{housing_pattern})
#         (?:\s+(?P<suffix>{suffix_pattern}))?
#         \b
#     '''

#     matches = re.finditer(match_pattern, description, flags=re.IGNORECASE | re.VERBOSE)
    
#     result = []
#     for match in matches:
#         qty = match.group("qty")
#         raw_type = match.group("type")
#         raw_mod = match.group("mod")
#         raw_suffix = match.group("suffix")

#         # Normalize type
#         norm_key = re.sub(r'[-\s]+', ' ', raw_type.lower()).strip()
#         normalized_type = term_map.get(norm_key, norm_key)

#         # Build output tuple
#         result.append((
#             int(qty),
#             raw_mod.lower() if raw_mod else None,
#             normalized_type,
#             raw_suffix.lower() if raw_suffix else None
#         ))

#     return result

# %%
def normalize_for_regex(term):
    return re.sub(r'[-\s]+', r'\\s*-?\\s*', term)

def extract_units(description):
    # Remove square footage references
    description = re.sub(
        r'(\d+|\d{1,3}(,\d{3})*)(\s+[A-Za-z-]+){0,2}?\s*(SF|square feet|sq\.?\s*ft\.?|sqft)',
        '', description, flags=re.IGNORECASE
    )

    # Map variations to standardized types
    term_map = {
        "home": "home", "homes": "home", "house": "home", "houses": "home",
        "duplex": "duplex", "duplexes": "duplex",
        "condo": "condo", "condominium": "condo", "condominiums": "condo", "condos": "condo", 
        "apartment": "apartment", "apartments": "apartment",
        "townhome": "townhouse", "townhomes": "townhouse",
        "townhouse": "townhouse", "townhouses": "townhouse",
        "town home": "townhouse", "town homes": "townhouse",
        "town house": "townhouse", "town houses": "townhouse",
        "multifamily": "multifamily", "multi-family": "multifamily", 
        "multi - family": "multifamily", "multi family": "multifamily",
        "mutifamily": "multifamily", "MF": "multifamily",
        "single family": "single family", "single-family": "single family", 
        "single - family": "single family", "s-f": "single family", "s - f": "single family", "s f": "single family"
    }

    modifiers = ["attached", "detached"]
    suffixes = ["units", "lots", "homes", "houses"]

    housing_pattern = "|".join([normalize_for_regex(term) for term in term_map])
    modifier_pattern = "|".join(modifiers)
    suffix_pattern = "|".join(suffixes)

    # Extended match pattern to support both "qty before type" and "type before qty"
    match_pattern = rf'''
    (?:
        # Qty before type
        (?P<qty>\(?\d{{1,4}}\)?)
        (?:\s*[-+&/]?\s*)?
        (?:({modifier_pattern})\s*){{0,2}}?
        (?:\w+\s*){{0,4}}?
        (?P<type>{housing_pattern})
        (?:\s+({modifier_pattern}))?
        (?:\s+(?P<suffix>{suffix_pattern}))?

    |
        # Type before qty
        (?P<type2>{housing_pattern})
        (?:\s+({modifier_pattern}))?
        (?:\s*[-+&/]?\s*)?
        (?:\w+\s*){{0,4}}?
        (?P<qty2>\(?\d{{1,4}}\)?)
        (?:\s+(?P<suffix2>{suffix_pattern}))?

    |
        # Type with quantity in parentheses
        (?P<type3>{housing_pattern})
        (?:\s+\w+){{0,4}}?
        \(\s*(?P<qty3>\d{{1,4}})\s+(?P<suffix3>{suffix_pattern})\s*\)
    )
'''

    matches = re.finditer(match_pattern, description, flags=re.IGNORECASE | re.VERBOSE)
    
    result = []
    for match in matches:
        qty = match.group("qty") or match.group("qty2")
        raw_type = match.group("type") or match.group("type2")
        raw_mod = match.group(2)  # first modifier (position varies)
        raw_suffix = match.group("suffix") or match.group("suffix2")

        if not qty or not raw_type:
            continue  # skip malformed matches

        # Normalize type
        norm_key = re.sub(r'[-\s]+', ' ', raw_type.lower()).strip()
        normalized_type = term_map.get(norm_key, norm_key)

        result.append((
            int(qty.strip("()")),
            raw_mod.lower() if raw_mod else None,
            normalized_type,
            raw_suffix.lower() if raw_suffix else None
        ))

    return result

# %%
filtered3['match_results'] = filtered3['A_DESCRIPT'].apply(extract_units)
# filtered3['match_results'] = filtered3['A_DESCRIPT'].apply(extract_units2)
filtered3 = filtered3.to_crs('EPSG:4326')
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# create a column for each relevant housing type
housing_types = ['sf_detached', 'sf_attached', 'duplex/triplex', 'multifamily', 'condo']
for h_type in housing_types: 
    filtered3[h_type] = 0

housing_type_dict = {
        'townhouse': 'sf_attached',
        'home': 'sf_detached', 'single family': 'sf_detached', 
        'duplex': 'duplex/triplex', 
        'apartment': 'multifamily', 'multifamily': 'multifamily', 
        'condo': 'condo'}
      
    
# function to fill in housing type columns
def fill_types(match_results):

    row_data = {h_type: 0 for h_type in housing_types}
    for group in match_results:
        
        quantity = int(group[0])
        mod = group[1] if len(group) > 1 else None
        housing = group[2] if len(group) > 2 else None
        
        if housing == 'single family' and mod == 'attached':
            row_data['sf_attached'] += quantity
        elif housing in housing_type_dict:
            row_data[housing_type_dict[housing]] += quantity
        else:
            pass

    return pd.Series(row_data)

# %%
filtered3[housing_types] = filtered3['match_results'].apply(fill_types)

# %%
'''
read in highschool boundaries shapefile -- file paths:
Kevan: r'C:\\Users\\kevan\\OneDrive\\Desktop\\Data+\\regions_2025_26\\regions_2025_26.shp'
Leah: '/Users/leahwallihan/Durham_school_planning/geospatial files/HS_regions'
'''
high_school_boundaries = gpd.read_file('/Users/leahwallihan/Durham_school_planning/geospatial files/HS_regions') 
high_school_boundaries = high_school_boundaries.to_crs('EPSG:4326')

# %%
filtered3_with_school = filtered3.copy()

for i,geometry in enumerate(high_school_boundaries['geometry']):
    in_geometry = geometry.contains(filtered3['geometry'])
    high_school_name = high_school_boundaries.loc[i, 'region']

    filtered3_with_school.loc[in_geometry, 'region'] = high_school_name

# %%
'''
read in planning unit shapefile -- file paths: 
Leah: /Users/leahwallihan/Durham_school_planning/geospatial files/pu_shape.geojson
'''

pu_shape = gpd.read_file('/Users/leahwallihan/Durham_school_planning/geospatial files/pu_shape.geojson')
pu_shape = pu_shape.to_crs('EPSG:4326')

# %%
# assign planning units to developments
filtered_with_shapes = filtered3_with_school.copy()

for i, geometry in enumerate(pu_shape['geometry']):
    in_geometry = geometry.contains(filtered3_with_school['geometry'])
    pu = pu_shape.loc[i, 'OBJECTID']

    filtered_with_shapes.loc[in_geometry, 'pu'] = pu

# %%
pd.set_option('display.max_colwidth', 60)
filtered_with_shapes[['A_DESCRIPT', 'sf_detached', 'multifamily', 'condo']].head(30)
# Out:
#                                                        A_DESCRIPT  \
# 90    50 Single - family lots, 1 stormwater pond, ad associate...
# 139   Mass grading only site plan for residential townhome pro...
# 224     Mixe of uses including retail and residential. Zoned DD-C
# 242                                        Multifamily Apartments
# 265   37 Townhome units, 102 Attached S-F units (called Duplex...
# 290   From Rural Density Residential (RDR, 0.5DU/acre or less)...
# 308   33 new town home lots with garages and mail kiosk with p...
# 336   32 single family units on small lots and 23 townhomes wi...
# 478   108 Single - Family lots, 2 stormwater ponds, and associ...
# 545   397,000 Total SF: Apartments (264 units), Accessory Uses...
# 554   This is a residential subdivision of a 20.96 acre tract ...
# 555                         2 New townhouses on vacant infill lot
# 581   100,000 SF mixed use development with associated surface...
# 593   Mixed used development with office, retail, residential ...
# 628                          82 unit affordable housing apartment
# 638   Proposed 25 S-F lots, 11 Townhomes lots, 2 condo units i...
# 761       Addition of temporary care housing for cancer patients.
# 839   Proposed 14 townhomes and 1 single-family home with an a...
# 859   11,600 SF four-story 3 unit townhome project with 2600 S...
# 956   Subdivision of existing property and construction of a p...
# 999                         89 Single family lots + 4 open spaces
# 1094  Industrial to Low-Medium Density Residential. Associated...
# 1351                                    Single Family Residential
# 1432  Construction of 268 multi-family units with associated a...
# 1472   201 townhome units proposed as a conservation subdivision.
# 1742  6 units + 4 ADU's and 974 s.f. of commercial space. 5 lo...
# 1896  Residential high rise building with parking and 1st floo...
# 1941  Rezoning from RR/RS-20 to PDR 5.943 to allow for up to 2...
# 2009  228 Multi - Family Apartment units and associated amenit...
# 2105  14 Attached homes w/ cul-de-sac road and utilities. Site...
#
#       sf_detached  multifamily  condo
# 90             50            0      0
# 139             0            0      0
# 224             0            0      0
# 242             0            0      0
# 265           248            0      0
# 290             0            0      0
# 308             0            0      0
# 336            32            0      0
# 478           108            0      0
# 545             0          264      0
# 554            49            0      0
# 555             0            0      0
# 581             0            0      0
# 593             0          343      0
# 628             0           82      0
# 638            25            0      2
# 761             0            0      0
# 839             1            0      0
# 859             0            0      0
# 956             0            0      0
# 999            89            0      0
# 1094            0            0      0
# 1351            0            0      0
# 1432            0          268      0
# 1472            0            0      0
# 1742            0            0      0
# 1896            0          242      0
# 1941            0            0      0
# 2009            0          228      0
# 2105           14            0      0

# %%
filtered_with_shapes
# Out:
#        A_NUMBER    A_TYPE     A_DATE A_STATUS A_STATUS_D  \
# 90     D2000291  PL_MINSP 2020-12-02      APP 2021-09-03
# 139    D2200173  PL_MINSP 2022-05-25      APP 2023-02-01
# 224    D1800378  PL_MINSP 2018-11-28      APP 2020-04-14
# 242    D2100156  PL_MINSP 2021-06-04      APP 2022-02-02
# 265    D1900171  PL_MINSP 2019-05-30      APP 2020-04-03
# ...         ...       ...        ...      ...        ...
# 21141  D2500072  PL_MINSP 2025-03-18    UN_RE 2025-03-18
# 21176  D2500088  PL_MINSP 2025-04-01    UN_RE 2025-04-01
# 21222  D2500095  PL_MINSP 2025-04-17    UN_RE 2025-04-17
# 21241  D2500103  PL_MINSP 2025-04-25    UN_RE 2025-04-25
# 21314  D2500120  PL_MINSP 2025-05-19    UN_RE 2025-05-19
#
#                                     A_PROJECT_  \
# 90      Umstead Grove Conservation Subdivision
# 139    Pineview Glen Town homes - Mass Grading
# 224                   Elan Innovation District
# 242                            ALTA Rutherford
# 265                         Ellis Road Phase 3
# ...                                        ...
# 21141                             Leigh Valley
# 21176                     Cornwallis Townhomes
# 21222        4702 Farrington Rd - Grading Only
# 21241            Fayetteville Road MultiFamily
# 21314               Courtyards at Oak Grove II
#
#                                                         A_DESCRIPT  \
# 90     50 Single - family lots, 1 stormwater pond, ad associate...
# 139    Mass grading only site plan for residential townhome pro...
# 224      Mixe of uses including retail and residential. Zoned DD-C
# 242                                         Multifamily Apartments
# 265    37 Townhome units, 102 Attached S-F units (called Duplex...
# ...                                                            ...
# 21141                  Apartment development to include 324 units.
# 21176                                     Create 33 townhome site.
# 21222   Grading only site plan for future residential development.
# 21241  Phase one of overall development - single family detache...
# 21314  36 Single Family Detached dwellings, 31 town homes and a...
#
#         A_USER_ID  A_CASE_PLA StatCode  ...       Editor  \
# 90      JESSICADO  COURTNEYMC      APP  ...  gisproc_sys
# 139       JUSTINH    KEAGANSA      APP  ...  gisproc_sys
# 224        JOHNRA      TREYFI      APP  ...  gisproc_sys
# 242         KIMRO      TREYFI      APP  ...  gisproc_sys
# 265       ROBINSH      COLERE      APP  ...  gisproc_sys
# ...           ...         ...      ...  ...          ...
# 21141   MICHAELMA      TREYFI    UN_RE  ...  gisproc_sys
# 21176  EARLENETHO    JALISAHA    UN_RE  ...  gisproc_sys
# 21222       NKOST    PEYTONBL    UN_RE  ...  gisproc_sys
# 21241  FRANCISCOM      TREYFI    UN_RE  ...  gisproc_sys
# 21314      ADDMGR      TREYFI    UN_RE  ...  gisproc_sys
#
#                          geometry  \
# 90     POINT (-78.94561 36.07501)
# 139    POINT (-78.81051 35.92776)
# 224    POINT (-78.90421 35.99991)
# 242    POINT (-78.92991 36.01005)
# 265     POINT (-78.86167 35.9519)
# ...                           ...
# 21141  POINT (-78.99141 35.91899)
# 21176   POINT (-78.8931 35.93767)
# 21222  POINT (-78.99077 35.93368)
# 21241  POINT (-78.94976 35.87877)
# 21314   POINT (-78.79654 35.9509)
#
#                                                      match_results  \
# 90                               [(50, None, single family, lots)]
# 139                                                             []
# 224                                                             []
# 242                                                             []
# 265    [(37, None, townhouse, units), (102, None, single family...
# ...                                                            ...
# 21141                              [(324, None, apartment, units)]
# 21176                                [(33, None, townhouse, None)]
# 21222                                                           []
# 21241                           [(88, None, single family, units)]
# 21314  [(36, None, single family, None), (31, None, townhouse, ...
#
#       sf_detached sf_attached  duplex/triplex multifamily condo     region  \
# 90             50           0               0           0     0      North
# 139             0           0               0           0     0       East
# 224             0           0               0           0     0    Central
# 242             0           0               0           0     0    Central
# 265           248          37               0           0     0       East
# ...           ...         ...             ...         ...   ...        ...
# 21141           0           0               0         324     0  Southwest
# 21176           0          33               0           0     0  Southeast
# 21222           0           0               0           0     0  Southwest
# 21241          88           0               0           0     0  Southeast
# 21314          36          31               0           0     0       East
#
#           pu
# 90     663.0
# 139    249.0
# 224    819.0
# 242    802.0
# 265    132.0
# ...      ...
# 21141  814.0
# 21176  515.0
# 21222  649.0
# 21241  256.0
# 21314  610.0
#
# [270 rows x 29 columns]

# %%
# filtered_with_shapes.to_file('resdev_cases.geojson', driver='GeoJSON')

# %%
'''
read in csv file for DPS development data -- file paths: 
Leah: /Users/leahwallihan/Durham_school_planning/CSV files/DPS_residential_developments.csv
'''

DPS_resdev = pd.read_csv('/Users/leahwallihan/Durham_school_planning/CSV files/DPS_residential_developments.csv')
DPS_resdev[['A_DESCRIPTION', 'PLNS_NUMBER_OF_LOTS', 'PLNS_NUMBER_OF_UNITS', 'PLNS_APARTMENTS', 'PLNS_TOWNHOMES', 'PLNS_CONDOMINIUMS']].head(20)
# Out:
#                                         A_DESCRIPTION  PLNS_NUMBER_OF_LOTS  \
# 0                              36 proposed townhomes.                  NaN
# 1   Changes to sub-phasing, lot depths and street ...                  NaN
# 2   various revisions made with this submittal inc...                  NaN
# 3   Changes to building layout, parking, and sidew...                 52.0
# 4   New townhome development with 53 units and new...                  NaN
# 5   Building footprint update with no additional i...                  NaN
# 6                            Changes to amenity area.                  NaN
# 7                      160 unit affordable apartment.                  NaN
# 8   208 Single-family, 186 townhouses, 8 apartment...                  NaN
# 9   Update the Site Plan to the approved CDs (Stor...                  NaN
# 10  22 proposed townhome units, playground, trail,...                 18.0
# 11  Increase pool deck size and adding impervious ...                  NaN
# 12             252 affordable unit apartment complex.                  NaN
# 13  Construction of 399 multi-family units with as...                  3.0
# 14                              Stream stabilization.                274.0
# 15  Updating stream and wetland based on determina...                  NaN
# 16  Phase one of overall development - single fami...                  NaN
# 17  Change to overall site area by adding a parcel...                  NaN
# 18        Revision to open space and tree save areas.                  NaN
# 19  100 townhomes with public water and sewer, pri...                  NaN
#
#     PLNS_NUMBER_OF_UNITS PLNS_APARTMENTS PLNS_TOWNHOMES PLNS_CONDOMINIUMS
# 0                  225.0               T            NaN               NaN
# 1                    NaN             NaN            NaN               NaN
# 2                    NaN             NaN            NaN               NaN
# 3                    NaN             NaN              T               NaN
# 4                    NaN             NaN              T               NaN
# 5                    NaN             NaN            NaN               NaN
# 6                    NaN             NaN            NaN               NaN
# 7                    NaN             NaN            NaN               NaN
# 8                   90.0               T            NaN               NaN
# 9                    NaN             NaN            NaN               NaN
# 10                 107.0               T              T               NaN
# 11                   NaN             NaN            NaN               NaN
# 12                   NaN             NaN            NaN               NaN
# 13                   NaN             NaN            NaN               NaN
# 14                   NaN             NaN            NaN               NaN
# 15                   NaN             NaN            NaN               NaN
# 16                   NaN             NaN            NaN               NaN
# 17                   NaN             NaN            NaN               NaN
# 18                   NaN             NaN            NaN               NaN
# 19                 339.0               T            NaN               NaN

# %%
pd.set_option('display.max_colwidth', 50)
filtered_with_shapes[['A_DESCRIPT', 'sf_detached', 'sf_attached', 'duplex/triplex', 'multifamily', 'condo']].head(20)
# Out:
#                                             A_DESCRIPT  sf_detached  \
# 90   50 Single - family lots, 1 stormwater pond, ad...           50
# 139  Mass grading only site plan for residential to...            0
# 224  Mixe of uses including retail and residential....            0
# 242                             Multifamily Apartments            0
# 265  37 Townhome units, 102 Attached S-F units (cal...          248
# 290  From Rural Density Residential (RDR, 0.5DU/acr...            0
# 308  33 new town home lots with garages and mail ki...            0
# 336  32 single family units on small lots and 23 to...           32
# 478  108 Single - Family lots, 2 stormwater ponds, ...          108
# 545  397,000 Total SF: Apartments (264 units), Acce...            0
# 554  This is a residential subdivision of a 20.96 a...           49
# 555              2 New townhouses on vacant infill lot            0
# 581  100,000 SF mixed use development with associat...            0
# 593  Mixed used development with office, retail, re...            0
# 628               82 unit affordable housing apartment            0
# 638  Proposed 25 S-F lots, 11 Townhomes lots, 2 con...           25
# 761  Addition of temporary care housing for cancer ...            0
# 839  Proposed 14 townhomes and 1 single-family home...            1
# 859  11,600 SF four-story 3 unit townhome project w...            0
# 956  Subdivision of existing property and construct...            0
#
#      sf_attached  duplex/triplex  multifamily  condo
# 90             0               0            0      0
# 139            0               0            0      0
# 224            0               0            0      0
# 242            0               0            0      0
# 265           37               0            0      0
# 290            0               0            0      0
# 308           33               0            0      0
# 336           23               0            0      0
# 478            0               0            0      0
# 545            0               0          264      0
# 554            0               0            0      0
# 555            2               0            0      0
# 581            0               0            0      0
# 593            0               0          343      0
# 628            0               0           82      0
# 638           11               0            0      2
# 761            0               0            0      0
# 839           14               0            0      0
# 859            3               0            0      0
# 956          176               0            0      0

# %%
filtered_with_shapes
# Out:
#        A_NUMBER    A_TYPE     A_DATE A_STATUS A_STATUS_D  \
# 90     D2000291  PL_MINSP 2020-12-02      APP 2021-09-03
# 139    D2200173  PL_MINSP 2022-05-25      APP 2023-02-01
# 224    D1800378  PL_MINSP 2018-11-28      APP 2020-04-14
# 242    D2100156  PL_MINSP 2021-06-04      APP 2022-02-02
# 265    D1900171  PL_MINSP 2019-05-30      APP 2020-04-03
# ...         ...       ...        ...      ...        ...
# 21141  D2500072  PL_MINSP 2025-03-18    UN_RE 2025-03-18
# 21176  D2500088  PL_MINSP 2025-04-01    UN_RE 2025-04-01
# 21222  D2500095  PL_MINSP 2025-04-17    UN_RE 2025-04-17
# 21241  D2500103  PL_MINSP 2025-04-25    UN_RE 2025-04-25
# 21314  D2500120  PL_MINSP 2025-05-19    UN_RE 2025-05-19
#
#                                     A_PROJECT_  \
# 90      Umstead Grove Conservation Subdivision
# 139    Pineview Glen Town homes - Mass Grading
# 224                   Elan Innovation District
# 242                            ALTA Rutherford
# 265                         Ellis Road Phase 3
# ...                                        ...
# 21141                             Leigh Valley
# 21176                     Cornwallis Townhomes
# 21222        4702 Farrington Rd - Grading Only
# 21241            Fayetteville Road MultiFamily
# 21314               Courtyards at Oak Grove II
#
#                                               A_DESCRIPT   A_USER_ID  \
# 90     50 Single - family lots, 1 stormwater pond, ad...   JESSICADO
# 139    Mass grading only site plan for residential to...     JUSTINH
# 224    Mixe of uses including retail and residential....      JOHNRA
# 242                               Multifamily Apartments       KIMRO
# 265    37 Townhome units, 102 Attached S-F units (cal...     ROBINSH
# ...                                                  ...         ...
# 21141        Apartment development to include 324 units.   MICHAELMA
# 21176                           Create 33 townhome site.  EARLENETHO
# 21222  Grading only site plan for future residential ...       NKOST
# 21241  Phase one of overall development - single fami...  FRANCISCOM
# 21314  36 Single Family Detached dwellings, 31 town h...      ADDMGR
#
#        A_CASE_PLA StatCode  ...       Editor                    geometry  \
# 90     COURTNEYMC      APP  ...  gisproc_sys  POINT (-78.94561 36.07501)
# 139      KEAGANSA      APP  ...  gisproc_sys  POINT (-78.81051 35.92776)
# 224        TREYFI      APP  ...  gisproc_sys  POINT (-78.90421 35.99991)
# 242        TREYFI      APP  ...  gisproc_sys  POINT (-78.92991 36.01005)
# 265        COLERE      APP  ...  gisproc_sys   POINT (-78.86167 35.9519)
# ...           ...      ...  ...          ...                         ...
# 21141      TREYFI    UN_RE  ...  gisproc_sys  POINT (-78.99141 35.91899)
# 21176    JALISAHA    UN_RE  ...  gisproc_sys   POINT (-78.8931 35.93767)
# 21222    PEYTONBL    UN_RE  ...  gisproc_sys  POINT (-78.99077 35.93368)
# 21241      TREYFI    UN_RE  ...  gisproc_sys  POINT (-78.94976 35.87877)
# 21314      TREYFI    UN_RE  ...  gisproc_sys   POINT (-78.79654 35.9509)
#
#                                            match_results sf_detached  \
# 90                     [(50, None, single family, lots)]          50
# 139                                                   []           0
# 224                                                   []           0
# 242                                                   []           0
# 265    [(37, None, townhouse, units), (102, None, sin...         248
# ...                                                  ...         ...
# 21141                    [(324, None, apartment, units)]           0
# 21176                      [(33, None, townhouse, None)]           0
# 21222                                                 []           0
# 21241                 [(88, None, single family, units)]          88
# 21314  [(36, None, single family, None), (31, None, t...          36
#
#       sf_attached  duplex/triplex multifamily condo     region     pu
# 90              0               0           0     0      North  663.0
# 139             0               0           0     0       East  249.0
# 224             0               0           0     0    Central  819.0
# 242             0               0           0     0    Central  802.0
# 265            37               0           0     0       East  132.0
# ...           ...             ...         ...   ...        ...    ...
# 21141           0               0         324     0  Southwest  814.0
# 21176          33               0           0     0  Southeast  515.0
# 21222           0               0           0     0  Southwest  649.0
# 21241           0               0           0     0  Southeast  256.0
# 21314          31               0           0     0       East  610.0
#
# [270 rows x 29 columns]

# %%
sol = gpd.read_file('gravity_model_sol.geojson')

# %%
sol['score'].idxmin()
# Out:
# 374

# %%
sol.plot(column = 'score', cmap='coolwarm')
# Out:
# <Axes: >

# %%
sol.iloc[374]
# Out:
# OBJECTID                                                      375
# pu_2324_84                                                    375
# X                                                   2029908.77692
# Y                                                   818792.765825
# M_min                                                         0.0
# PS_ID                                                         439
# PUID2122_2                                                    439
# ps_id_833                                                     506
# psid_982                                                      506
# TIMS_PU                                                     PU439
# Region                                                    Central
# Shape_Length                                         11444.028976
# Shape_Area                                          8461858.72853
# score                                                    2.791209
# geometry        POLYGON ((-8782744.76053158 4300025.661254817,...
# Name: 374, dtype: object
